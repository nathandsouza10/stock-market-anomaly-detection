# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('./anomaly-class-detection/train/train.csv')
y = X.pop('result')
X
# Out:
#         exchange        RSI RSI_signal       ATR  EMA_relative  MA_relative  \
# 0             BC  32.000000       Hold  0.000347      1.002286     1.002714
# 1             BC  48.648649       Hold  0.000513      0.998955     0.999231
# 2             BC  21.428571        Buy  0.000413      1.002658     1.003332
# 3             BC  38.297872       Hold  0.000527      1.000234     1.000465
# 4             BC  37.566138       Hold  0.002780      1.001247     1.001720
# ...          ...        ...        ...       ...           ...          ...
# 3335035       BC  69.444444       Hold  0.005533      0.997982     0.997487
# 3335036       BC  56.000000       Hold  0.003200      0.997922     0.998137
# 3335037       OK  48.333333       Hold  7.266667      1.001335     1.001346
# 3335038       OK  50.000000       Hold  0.000167      1.000667     1.000684
# 3335039       OK  27.272727        Buy  0.002400      1.000232     1.000732
#
#          SMA_relative  WMA_relative      MACD  MACD_relative  ...  \
# 0           -0.270648     -0.002280 -0.000136      -0.000455  ...
# 1            0.076998      0.001080 -0.000196      -0.000613  ...
# 2           -0.332120     -0.002628 -0.000412      -0.001321  ...
# 3           -0.046505     -0.000180 -0.000282      -0.000936  ...
# 4           -0.171722     -0.001204  0.000670       0.002009  ...
# ...               ...           ...       ...            ...  ...
# 3335035      0.251931      0.002051  0.003619       0.000988  ...
# 3335036      0.186683      0.002220 -0.001749      -0.001086  ...
# 3335037     -0.134441     -0.001342  1.216706       0.000175  ...
# 3335038     -0.068329     -0.000695 -0.000009      -0.000066  ...
# 3335039     -0.073161     -0.000105 -0.003736      -0.001172  ...
#
#          Bollinger_upper_band  Bollinger_lower_band  Bollinger_signal  \
# 0                    0.001013             -0.006569              Hold
# 1                    0.004261             -0.003543              Hold
# 2                    0.001150             -0.008747              Hold
# 3                    0.001933             -0.004423              Hold
# 4                    0.024233             -0.024503              Hold
# ...                       ...                   ...               ...
# 3335035              0.006880             -0.000990              Hold
# 3335036              0.005385             -0.002959              Hold
# 3335037              0.003247             -0.005668              Hold
# 3335038              0.004315             -0.005486              Hold
# 3335039              0.002563             -0.004944              Hold
#
#          ichimoku_c_conversion_line  ichimoku_c_base_line  \
# 0                      2.168836e-01              0.166834
# 1                     -9.357455e-02             -0.093575
# 2                      2.723486e-01              0.608779
# 3                     -4.985045e-02              0.099701
# 4                     -3.000300e-02             -0.765077
# ...                             ...                   ...
# 3335035               -2.321770e-01             -0.355094
# 3335036               -2.795031e-01             -0.062112
# 3335037                1.370258e-01             -0.072119
# 3335038                1.098901e-01              0.109890
# 3335039                1.393440e-14              0.188265
#
#          ichimoku_c_leading_span_a  ichimoku_c_leading_span_b  \
# 0                         0.417084                   0.483817
# 1                        -0.015596                  -0.171553
# 2                         0.368472                  -0.144185
# 3                         0.324028                   0.598205
# 4                        -5.670567                  -5.205521
# ...                            ...                        ...
# 3335035                  -0.273149                  -0.382409
# 3335036                   0.496894                   0.496894
# 3335037                  -0.641858                  -0.771672
# 3335038                  -0.787546                  -0.586081
# 3335039                   0.188265                   0.015689
#
#         ichimoku_c_signal  SAR_relative  s&p500_move_15m
# 0                    Sell      0.282722        -2.927393
# 1                     Buy     -0.086598        -4.592614
# 2                     Buy      0.286055        -0.833371
# 3                    Sell      0.113799        -1.242264
# 4                    Sell      0.250892        -0.786651
# ...                   ...           ...              ...
# 3335035               Buy     -0.294609        -0.131818
# 3335036               Buy     -0.340927        -0.546764
# 3335037               Buy      0.106855        -0.005045
# 3335038              Sell      0.046107        -0.308752
# 3335039               Buy      0.080835         0.000681
#
# [3335040 rows x 38 columns]

# %%
X_test = pd.read_csv('./anomaly-class-detection/test.csv', index_col='id')
X_test
# Out:
#        exchange        RSI RSI_signal        ATR  EMA_relative  MA_relative  \
# id
# 0            BC  55.265610       Hold  13.913333      1.000181     1.000026
# 1            BC  30.530973       Hold  15.593333      1.000436     1.000603
# 2            BC  29.121726        Buy  17.486667      1.000794     1.001058
# 3            BC  27.715356        Buy  10.286667      1.000553     1.000700
# 4            BC  46.851211       Hold  12.566667      1.000236     1.000358
# ...         ...        ...        ...        ...           ...          ...
# 114577       HB  41.750842       Hold   0.000290      1.000577     1.000578
# 114578       HB  25.870647        Buy   0.000279      1.000733     1.001560
# 114579       HB  66.836735       Hold   0.000294      0.998322     0.997801
# 114580       HB  58.479532       Hold   0.000225      0.999314     0.999257
# 114581       HB  29.680365        Buy   0.000265      1.001536     1.002058
#
#         SMA_relative  WMA_relative       MACD  MACD_relative  ...  \
# id                                                            ...
# 0          -0.002551     -0.000239  10.689502       0.000405  ...
# 1          -0.060300     -0.000418 -13.493144      -0.000512  ...
# 2          -0.105689     -0.000766 -14.701974      -0.000559  ...
# 3          -0.069978     -0.000566  -7.428207      -0.000283  ...
# 4          -0.035742     -0.000217  -4.157181      -0.000158  ...
# ...              ...           ...        ...            ...  ...
# 114577     -0.057781     -0.000582  -0.000120      -0.000566  ...
# 114578     -0.155732     -0.000622  -0.000312      -0.001483  ...
# 114579      0.220414      0.001672   0.000216       0.001023  ...
# 114580      0.074392      0.000691   0.000145       0.000684  ...
# 114581     -0.205378     -0.001524  -0.000228      -0.001082  ...
#
#         Bollinger_upper_band  Bollinger_lower_band  Bollinger_signal  \
# id
# 0                   0.001787             -0.001383              Hold
# 1                   0.000733             -0.002635              Hold
# 2                   0.000196             -0.002939              Hold
# 3                   0.000732             -0.002377              Hold
# 4                   0.001202             -0.001777              Hold
# ...                      ...                   ...               ...
# 114577              0.004314             -0.006879              Hold
# 114578              0.003349             -0.007838              Hold
# 114579              0.007390             -0.001571              Hold
# 114580              0.005670             -0.003252              Hold
# 114581              0.001829             -0.007115              Hold
#
#         ichimoku_c_conversion_line  ichimoku_c_base_line  \
# id
# 0                         0.065536             -0.005303
# 1                         0.057680              0.181010
# 2                         0.081365              0.157408
# 3                         0.074947              0.104242
# 4                         0.005706              0.056295
# ...                            ...                   ...
# 114577                    0.111364              0.206142
# 114578                    0.126016              0.259166
# 114579                   -0.156191             -0.265051
# 114580                   -0.073234             -0.255138
# 114581                    0.151976              0.284954
#
#         ichimoku_c_leading_span_a  ichimoku_c_leading_span_b  \
# id
# 0                       -0.122169                  -0.128040
# 1                        0.051419                   0.108530
# 2                        0.304075                   0.302649
# 3                        0.418012                   0.363704
# 4                        0.297737                   0.372765
# ...                           ...                        ...
# 114577                   1.088759                   1.023600
# 114578                   1.222122                   1.562128
# 114579                   0.308832                   0.939512
# 114580                  -0.121663                   0.333097
# 114581                   0.192344                   0.726634
#
#        ichimoku_c_signal  SAR_relative  s&p500_move_15m
# id
# 0                    Buy      0.052812        -0.173499
# 1                   Sell      0.060480        -0.193533
# 2                    Buy      0.076881        -0.060834
# 3                    Buy      0.075752         0.018642
# 4                   Sell      0.034349         0.243439
# ...                  ...           ...              ...
# 114577               Buy      0.054950        -0.316902
# 114578              Sell      0.102489         0.065787
# 114579              Sell     -0.214776         0.126512
# 114580              Sell     -0.074758         0.063176
# 114581              Sell      0.242367         0.029085
#
# [114582 rows x 38 columns]

# %%
cat_desc = X.describe(include='object')
cat_desc
# Out:
#        exchange RSI_signal Stoch_O_signal fibonacci_signal Bollinger_signal  \
# count   3335040    3335040        3335040          3335040          3335040
# unique        4          3              3                3                3
# top          BB       Hold           Sell             Sell             Hold
# freq    1201702    2452197        3062281          1697351          3076880
#
#        ichimoku_c_signal
# count            3335040
# unique                 3
# top                  Buy
# freq             1665849

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()
X[cat_desc.columns.to_list()] = ordinal_encoder.fit_transform(X[cat_desc.columns.to_list()])
X
# Out:
#          exchange        RSI  RSI_signal       ATR  EMA_relative  MA_relative  \
# 0             1.0  32.000000         1.0  0.000347      1.002286     1.002714
# 1             1.0  48.648649         1.0  0.000513      0.998955     0.999231
# 2             1.0  21.428571         0.0  0.000413      1.002658     1.003332
# 3             1.0  38.297872         1.0  0.000527      1.000234     1.000465
# 4             1.0  37.566138         1.0  0.002780      1.001247     1.001720
# ...           ...        ...         ...       ...           ...          ...
# 3335035       1.0  69.444444         1.0  0.005533      0.997982     0.997487
# 3335036       1.0  56.000000         1.0  0.003200      0.997922     0.998137
# 3335037       3.0  48.333333         1.0  7.266667      1.001335     1.001346
# 3335038       3.0  50.000000         1.0  0.000167      1.000667     1.000684
# 3335039       3.0  27.272727         0.0  0.002400      1.000232     1.000732
#
#          SMA_relative  WMA_relative      MACD  MACD_relative  ...  \
# 0           -0.270648     -0.002280 -0.000136      -0.000455  ...
# 1            0.076998      0.001080 -0.000196      -0.000613  ...
# 2           -0.332120     -0.002628 -0.000412      -0.001321  ...
# 3           -0.046505     -0.000180 -0.000282      -0.000936  ...
# 4           -0.171722     -0.001204  0.000670       0.002009  ...
# ...               ...           ...       ...            ...  ...
# 3335035      0.251931      0.002051  0.003619       0.000988  ...
# 3335036      0.186683      0.002220 -0.001749      -0.001086  ...
# 3335037     -0.134441     -0.001342  1.216706       0.000175  ...
# 3335038     -0.068329     -0.000695 -0.000009      -0.000066  ...
# 3335039     -0.073161     -0.000105 -0.003736      -0.001172  ...
#
#          Bollinger_upper_band  Bollinger_lower_band  Bollinger_signal  \
# 0                    0.001013             -0.006569               1.0
# 1                    0.004261             -0.003543               1.0
# 2                    0.001150             -0.008747               1.0
# 3                    0.001933             -0.004423               1.0
# 4                    0.024233             -0.024503               1.0
# ...                       ...                   ...               ...
# 3335035              0.006880             -0.000990               1.0
# 3335036              0.005385             -0.002959               1.0
# 3335037              0.003247             -0.005668               1.0
# 3335038              0.004315             -0.005486               1.0
# 3335039              0.002563             -0.004944               1.0
#
#          ichimoku_c_conversion_line  ichimoku_c_base_line  \
# 0                      2.168836e-01              0.166834
# 1                     -9.357455e-02             -0.093575
# 2                      2.723486e-01              0.608779
# 3                     -4.985045e-02              0.099701
# 4                     -3.000300e-02             -0.765077
# ...                             ...                   ...
# 3335035               -2.321770e-01             -0.355094
# 3335036               -2.795031e-01             -0.062112
# 3335037                1.370258e-01             -0.072119
# 3335038                1.098901e-01              0.109890
# 3335039                1.393440e-14              0.188265
#
#          ichimoku_c_leading_span_a  ichimoku_c_leading_span_b  \
# 0                         0.417084                   0.483817
# 1                        -0.015596                  -0.171553
# 2                         0.368472                  -0.144185
# 3                         0.324028                   0.598205
# 4                        -5.670567                  -5.205521
# ...                            ...                        ...
# 3335035                  -0.273149                  -0.382409
# 3335036                   0.496894                   0.496894
# 3335037                  -0.641858                  -0.771672
# 3335038                  -0.787546                  -0.586081
# 3335039                   0.188265                   0.015689
#
#          ichimoku_c_signal  SAR_relative  s&p500_move_15m
# 0                      2.0      0.282722        -2.927393
# 1                      0.0     -0.086598        -4.592614
# 2                      0.0      0.286055        -0.833371
# 3                      2.0      0.113799        -1.242264
# 4                      2.0      0.250892        -0.786651
# ...                    ...           ...              ...
# 3335035                0.0     -0.294609        -0.131818
# 3335036                0.0     -0.340927        -0.546764
# 3335037                0.0      0.106855        -0.005045
# 3335038                2.0      0.046107        -0.308752
# 3335039                0.0      0.080835         0.000681
#
# [3335040 rows x 38 columns]

# %%
#using same ordinal_encoder object to transform test set
X_test[cat_desc.columns.to_list()] = ordinal_encoder.transform(X_test[cat_desc.columns.to_list()])
X_test
# Out:
#         exchange        RSI  RSI_signal        ATR  EMA_relative  MA_relative  \
# id
# 0            1.0  55.265610         1.0  13.913333      1.000181     1.000026
# 1            1.0  30.530973         1.0  15.593333      1.000436     1.000603
# 2            1.0  29.121726         0.0  17.486667      1.000794     1.001058
# 3            1.0  27.715356         0.0  10.286667      1.000553     1.000700
# 4            1.0  46.851211         1.0  12.566667      1.000236     1.000358
# ...          ...        ...         ...        ...           ...          ...
# 114577       2.0  41.750842         1.0   0.000290      1.000577     1.000578
# 114578       2.0  25.870647         0.0   0.000279      1.000733     1.001560
# 114579       2.0  66.836735         1.0   0.000294      0.998322     0.997801
# 114580       2.0  58.479532         1.0   0.000225      0.999314     0.999257
# 114581       2.0  29.680365         0.0   0.000265      1.001536     1.002058
#
#         SMA_relative  WMA_relative       MACD  MACD_relative  ...  \
# id                                                            ...
# 0          -0.002551     -0.000239  10.689502       0.000405  ...
# 1          -0.060300     -0.000418 -13.493144      -0.000512  ...
# 2          -0.105689     -0.000766 -14.701974      -0.000559  ...
# 3          -0.069978     -0.000566  -7.428207      -0.000283  ...
# 4          -0.035742     -0.000217  -4.157181      -0.000158  ...
# ...              ...           ...        ...            ...  ...
# 114577     -0.057781     -0.000582  -0.000120      -0.000566  ...
# 114578     -0.155732     -0.000622  -0.000312      -0.001483  ...
# 114579      0.220414      0.001672   0.000216       0.001023  ...
# 114580      0.074392      0.000691   0.000145       0.000684  ...
# 114581     -0.205378     -0.001524  -0.000228      -0.001082  ...
#
#         Bollinger_upper_band  Bollinger_lower_band  Bollinger_signal  \
# id
# 0                   0.001787             -0.001383               1.0
# 1                   0.000733             -0.002635               1.0
# 2                   0.000196             -0.002939               1.0
# 3                   0.000732             -0.002377               1.0
# 4                   0.001202             -0.001777               1.0
# ...                      ...                   ...               ...
# 114577              0.004314             -0.006879               1.0
# 114578              0.003349             -0.007838               1.0
# 114579              0.007390             -0.001571               1.0
# 114580              0.005670             -0.003252               1.0
# 114581              0.001829             -0.007115               1.0
#
#         ichimoku_c_conversion_line  ichimoku_c_base_line  \
# id
# 0                         0.065536             -0.005303
# 1                         0.057680              0.181010
# 2                         0.081365              0.157408
# 3                         0.074947              0.104242
# 4                         0.005706              0.056295
# ...                            ...                   ...
# 114577                    0.111364              0.206142
# 114578                    0.126016              0.259166
# 114579                   -0.156191             -0.265051
# 114580                   -0.073234             -0.255138
# 114581                    0.151976              0.284954
#
#         ichimoku_c_leading_span_a  ichimoku_c_leading_span_b  \
# id
# 0                       -0.122169                  -0.128040
# 1                        0.051419                   0.108530
# 2                        0.304075                   0.302649
# 3                        0.418012                   0.363704
# 4                        0.297737                   0.372765
# ...                           ...                        ...
# 114577                   1.088759                   1.023600
# 114578                   1.222122                   1.562128
# 114579                   0.308832                   0.939512
# 114580                  -0.121663                   0.333097
# 114581                   0.192344                   0.726634
#
#         ichimoku_c_signal  SAR_relative  s&p500_move_15m
# id
# 0                     0.0      0.052812        -0.173499
# 1                     2.0      0.060480        -0.193533
# 2                     0.0      0.076881        -0.060834
# 3                     0.0      0.075752         0.018642
# 4                     2.0      0.034349         0.243439
# ...                   ...           ...              ...
# 114577                0.0      0.054950        -0.316902
# 114578                2.0      0.102489         0.065787
# 114579                2.0     -0.214776         0.126512
# 114580                2.0     -0.074758         0.063176
# 114581                2.0      0.242367         0.029085
#
# [114582 rows x 38 columns]

# %% [markdown]
# EDA

# %% [markdown]
# Our dataset is imbalanced

# %%
y.value_counts()
# Out:
# 1    2970418
# 0     364622
# Name: result, dtype: int64

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)
X_reduced = pca.fit_transform(X)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
param_grid = {'C': [0.1, 1, 10], 'penalty': ['l1', 'l2']}
grid = GridSearchCV(LogisticRegression(), param_grid, refit=True, n_jobs=-1, scoring='f1')
grid.fit(X, y)
grid.best_score_

# %%
from sklearn.ensemble import RandomForestClassifier
param_grid = {'n_estimators': [10, 50, 100], 'max_depth': [None, 5, 10]}
grid = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, scoring='f1')
grid.fit(X, y)
grid.best_score_

# %%
from sklearn.naive_bayes import GaussianNB

param_grid = {'var_smoothing': [1e-9, 1e-8, 1e-7], 'priors': [None, [0.5, 0.5], [0.4, 0.6]]}
grid = GridSearchCV(GaussianNB(), param_grid, refit=True, n_jobs=-1, scoring='f1')
grid.fit(X, y)
print(grid.best_score_)

# %%
from sklearn.svm import SVC
param_grid = {'C': [0.1, 1, 10], 'gamma': [0.1, 1, 10]}
grid = GridSearchCV(SVC(), param_grid, refit=True, n_jobs=-1, scoring='f1')
grid.fit(X, y)
grid.best_score_
